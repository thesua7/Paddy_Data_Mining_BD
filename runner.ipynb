# %%
import pandas as pd
import matplotlib.pyplot as mplt
import seaborn as sns
import numpy as np

# %%
data=pd.read_csv(r'paddy_weather.csv')

# %%
data
# Out:
#       YEAR        Date  Temperature  Humidity  Precipitation  Wind  Moisture  \
# 0     2016    1/1/2016        19.52     74.12            0.0  1.27      0.66
# 1     2016    1/2/2016        19.80     71.12            0.0  1.27      0.65
# 2     2016    1/3/2016        19.48     70.81            0.0  1.10      0.65
# 3     2016    1/4/2016        19.04     72.50            0.0  1.38      0.64
# 4     2016    1/5/2016        18.82     73.75            0.0  1.31      0.64
# ...    ...         ...          ...       ...            ...   ...       ...
# 1822  2020  12/27/2020        17.48     80.00            0.0  1.74      0.80
# 1823  2020  12/28/2020        17.40     77.75            0.0  1.57      0.80
# 1824  2020  12/29/2020        17.05     79.88            0.0  1.81      0.80
# 1825  2020  12/30/2020        17.47     81.69            0.0  1.85      0.79
# 1826  2020  12/31/2020        18.16     80.62            0.0  1.42      0.79
#
#      Crops
# 0     Boro
# 1     Boro
# 2     Boro
# 3     Boro
# 4     Boro
# ...    ...
# 1822  Boro
# 1823  Boro
# 1824  Boro
# 1825  Boro
# 1826  Boro
#
# [1827 rows x 8 columns]

# %%
data.describe()
# Out:
#               YEAR  Temperature     Humidity  Precipitation         Wind  \
# count  1827.000000  1827.000000  1827.000000    1827.000000  1827.000000
# mean   2018.000000    25.468139    80.900367      14.658692     2.302573
# std       1.415375     3.715358     8.983976      30.440793     1.143023
# min    2016.000000    13.640000    44.810000       0.000000     0.620000
# 25%    2017.000000    22.760000    75.380000       0.000000     1.450000
# 50%    2018.000000    27.170000    82.940000       2.400000     1.950000
# 75%    2019.000000    28.215000    88.155000      16.275000     2.910000
# max    2020.000000    30.510000    94.690000     395.800000     8.720000
#
#           Moisture
# count  1827.000000
# mean      0.795003
# std       0.179373
# min       0.380000
# 25%       0.660000
# 50%       0.860000
# 75%       0.950000
# max       1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1827 entries, 0 to 1826
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   YEAR           1827 non-null   int64
#  1   Date           1827 non-null   object
#  2   Temperature    1827 non-null   float64
#  3   Humidity       1827 non-null   float64
#  4   Precipitation  1827 non-null   float64
#  5   Wind           1827 non-null   float64
#  6   Moisture       1827 non-null   float64
#  7   Crops          1827 non-null   object
# dtypes: float64(5), int64(1), object(2)
# memory usage: 114.3+ KB

# %%
data.isnull().sum()
# Out:
# YEAR             0
# Date             0
# Temperature      0
# Humidity         0
# Precipitation    0
# Wind             0
# Moisture         0
# Crops            0
# dtype: int64

# %% [markdown]
# #  Exploratory Data Analysis

# %%
# Histogram

# %%
data.hist(figsize=(14,12))
mplt.show()

# %%
# Pair Plot

# %%
data.reset_index(inplace=True)

sns.pairplot(data)
mplt.show()

# %%
# Correlation Matrix

# %%
size = 10
df = pd.DataFrame(data)
 
corrM = df.corr()
sns.heatmap(corrM, annot=True)
figure = mplt.gcf()
figure.set_size_inches(10,8)

mplt.show()

# %%
# Box Plotting

# %%
data.boxplot(figsize=(14,7))
# Out:
# <AxesSubplot:>
